# %%
import scipy
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import minimum_spanning_tree
import scipy.io as sio
from scipy.spatial import distance

# %%
df = pd.read_csv('first_4_cat.csv', index_col=0)

# %%
labels = np.loadtxt('label4cat.txt')

# %%
gmma = 0.5/(np.var(df.values)**2)

# %%
from sklearn.metrics.pairwise import rbf_kernel

T = df.values

dist_rbf = rbf_kernel(T,T,gamma = gmma)
dist_df = pd.DataFrame(data=dist_rbf)

# %%
dist_rbf = 1-dist_df.values
dist_df2 = pd.DataFrame(data=dist_rbf)
dist_df2
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.787987  0.969454  0.975945  0.870586  0.876518  0.958276
# 1    0.787987  0.000000  0.975517  0.971888  0.918702  0.915279  0.978525
# 2    0.969454  0.975517  0.000000  0.942173  0.969779  0.935314  0.943047
# 3    0.975945  0.971888  0.942173  0.000000  0.828711  0.791780  0.865591
# 4    0.870586  0.918702  0.969779  0.828711  0.000000  0.674937  0.921034
# 5    0.876518  0.915279  0.935314  0.791780  0.674937  0.000000  0.892027
# 6    0.958276  0.978525  0.943047  0.865591  0.921034  0.892027  0.000000
# 7    0.882370  0.884395  0.935504  0.860609  0.866688  0.823931  0.908118
# 8    0.982982  0.971183  0.958121  0.757931  0.962382  0.928308  0.899650
# 9    0.798520  0.795034  0.967879  0.950558  0.902225  0.807166  0.947077
# 10   0.919531  0.952256  0.930658  0.850395  0.686285  0.817271  0.928064
# 11   0.893203  0.876237  0.946895  0.786761  0.732370  0.720040  0.861379
# ...
